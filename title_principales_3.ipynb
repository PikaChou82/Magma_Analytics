# %% [markdown]
# <a href="https://colab.research.google.com/github/PikaChou82/Magma_Analytics/blob/main/title_principales_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive
from google.colab import files
drive.mount('/content/drive')

title_principales_3 = pd.read_csv("/content/drive/MyDrive/Donnees_projets2/dataset2/title.principals.tsv",
                                  sep='\t', skiprows=36000001, nrows=18000000, encoding='utf-8', header = 0)
# Out:
# Mounted at /content/drive

# %%
title_principales_3.columns = ['tconst', 'ordering', 'nconst', 'category', 'job', 'characters']

# %%
title_principales_3
# Out:
#               tconst  ordering      nconst  category          job  \
# 0         tt16138920         2  nm11212481    writer        words
# 1         tt16138920         3  nm11212481  producer     producer
# 2         tt16138922         1   nm1931264      self           \N
# 3         tt16138922         2   nm2626167      self           \N
# 4         tt16138922         3   nm2627659      self           \N
# ...              ...       ...         ...       ...          ...
# 17999995  tt27868366         1   nm2369818      self           \N
# 17999996  tt27868366         2   nm3941854    writer       writer
# 17999997  tt27868366         3   nm2962801    writer  head writer
# 17999998  tt27868366         4   nm2933112    writer       writer
# 17999999  tt27868366         5   nm0567134    writer       writer
#
#                     characters
# 0                           \N
# 1                           \N
# 2              ["Self - Host"]
# 3         ["Self - Housemate"]
# ...

# %%
title_movies = pd.read_csv("/content/drive/MyDrive/Donnees_projets2/title_movies_fr_60+_85+.csv",
                            sep=',', encoding='utf-8', header=0)

# %%
print(title_movies.head())
# Out:
#      titleId                 title region language        types attributes  \
# 0  tt0035423       Kate et Léopold     FR       \N  imdbDisplay         \N
# 1  tt0036606    Les Coeurs captifs     FR       \N  imdbDisplay         \N
# 2  tt0039442  Parle, petite muette     FR       \N  imdbDisplay         \N
# 3  tt0044952            Le citoyen     FR       \N           \N         \N
# 4  tt0045689    Le drame d'une vie     FR       \N  imdbDisplay         \N
#
#   titleType                   primaryTitle  isAdult  startYear  ...  \
# 0     movie                 Kate & Leopold      0.0       2001  ...
# 1     movie    Another Time, Another Place      0.0       1983  ...
# 2     movie                  Habla, mudita      0.0       1973  ...
# 3     movie                        Nagarik      0.0       1977  ...
# 4     movie  10 canzoni d'amore da salvare      0.0       1962  ...
#
#   runtimeMinutes   genres  directors                                  writers  \
# ...

# %%
title_merged = pd.merge(title_principales_3, title_movies, left_on='tconst', right_on='titleId')

# %%
title_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49840 entries, 0 to 49839
# Data columns (total 21 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   titleId              49840 non-null  object
#  1   title                49840 non-null  object
#  2   region               49840 non-null  object
#  3   language             49840 non-null  object
#  4   types                49840 non-null  object
#  5   attributes           49840 non-null  object
#  6   titleType            49840 non-null  object
#  7   primaryTitle         49840 non-null  object
#  8   isAdult              49840 non-null  float64
#  9   startYear            49840 non-null  int64
#  10  endYear              49840 non-null  object
#  11  runtimeMinutes       49840 non-null  int64
#  12  genres               49840 non-null  object
#  13  directors            49788 non-null  object
#  14  writers              49788 non-null  object
# ...

# %%
title_principales_3.shape
# Out:
# (18000000, 6)

# %%
title_merged.shape
# Out:
# (106192, 27)

# %%
title_merged.head()
# Out:
#        tconst  ordering      nconst category job             characters  \
# 0  tt16139258         1   nm3289096    actor  \N        ["Arun Katyal"]
# 1  tt16139258         2   nm5637317  actress  \N  ["Priyamvada Katyal"]
# 2  tt16139258         3   nm7796669  actress  \N              ["Laila"]
# 3  tt16139258         4  nm10808978    actor  \N          ["Terrorist"]
# 4  tt16139258         5   nm9895206  actress  \N              ["Tanya"]
#
#       titleId  title region language  ... runtimeMinutes  genres  \
# 0  tt16139258  Yodha     FR       \N  ...            130  Action
# 1  tt16139258  Yodha     FR       \N  ...            130  Action
# 2  tt16139258  Yodha     FR       \N  ...            130  Action
# 3  tt16139258  Yodha     FR       \N  ...            130  Action
# 4  tt16139258  Yodha     FR       \N  ...            130  Action
#
#              directors    writers  averageRating  numVotes note_ponderee  \
# ...
